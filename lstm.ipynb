# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, accuracy_score

# %%
import os


files = [
    'smote.csv',
    'adasyn.csv',
    'borderline_smote.csv',
    'tomek_links.csv',
    'smoteenn.csv',
    'smotetomek.csv'
]
target = 'techniques_mitre'

# %%
def lstm(file):
    folder = r'..\Dataset_simulazione'
    file_path = os.path.join(folder, file)
    new_df= pd.read_csv(file_path)


    # Initialize LabelEncoder for the target manually
    label_encoder = LabelEncoder()

    # Apply LabelEncoder to the target column
    new_df['techniques_mitre'] = label_encoder.fit_transform(new_df['techniques_mitre'])

    # Encoding the target variable to categorical
    y = new_df['techniques_mitre']
    y_categorical = to_categorical(y)  # Suitable for multi-class classification

    # Prepare features
    X = new_df.drop('techniques_mitre', axis=1).values

    # Reshape X to be suitable for LSTM [samples, timesteps, features]
    X = X.reshape((X.shape[0], X.shape[1], 1))

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size=0.2, random_state=42)

    # Normalize features
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
    X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

    # Define the LSTM model
    model = Sequential([
        Input(shape=(X_train.shape[1], 1)),  # Input layer defining the shape
        LSTM(50),  # LSTM layer with 50 units
        Dense(y_categorical.shape[1], activation='softmax')  # Output layer for classification
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.1)

    # Predict the test set
    y_pred_prob = model.predict(X_test)
    y_pred = np.argmax(y_pred_prob, axis=1)  # Convert probabilities to class labels
    y_true = np.argmax(y_test, axis=1)  # True labels

    # Evaluate the model
    accuracy = accuracy_score(y_true, y_pred)
    print(file, "Accuracy:", accuracy)

    # Classification Report - Ensure labels are strings
    target_names = label_encoder.inverse_transform(np.unique(new_df['techniques_mitre']))

    print("Classification Report:")
    print(classification_report(y_true, y_pred, target_names=target_names.astype(str), zero_division=0))

# %%
for file in files:
    lstm(file)
# Out:
# Epoch 1/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 82s 3ms/step - accuracy: 0.5372 - loss: 1.3534 - val_accuracy: 0.7050 - val_loss: 0.8991
# Epoch 2/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 79s 3ms/step - accuracy: 0.7128 - loss: 0.8726 - val_accuracy: 0.7549 - val_loss: 0.7154
# Epoch 3/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 79s 3ms/step - accuracy: 0.7572 - loss: 0.7096 - val_accuracy: 0.7767 - val_loss: 0.6389
# Epoch 4/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 78s 3ms/step - accuracy: 0.7780 - loss: 0.6393 - val_accuracy: 0.7855 - val_loss: 0.6065
# Epoch 5/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 79s 3ms/step - accuracy: 0.7912 - loss: 0.5954 - val_accuracy: 0.7987 - val_loss: 0.5749
# Epoch 6/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 79s 3ms/step - accuracy: 0.7990 - loss: 0.5648 - val_accuracy: 0.8043 - val_loss: 0.5400
# Epoch 7/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 80s 3ms/step - accuracy: 0.8056 - loss: 0.5397 - val_accuracy: 0.8097 - val_loss: 0.5219
# Epoch 8/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 80s 3ms/step - accuracy: 0.8095 - loss: 0.5196 - val_accuracy: 0.8155 - val_loss: 0.4947
# Epoch 9/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 79s 3ms/step - accuracy: 0.8142 - loss: 0.5017 - val_accuracy: 0.8174 - val_loss: 0.5048
# Epoch 10/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 75s 3ms/step - accuracy: 0.8165 - loss: 0.4895 - val_accuracy: 0.8208 - val_loss: 0.4799
# 6496/6496 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# smote.csv Accuracy: 0.8194309467222185
# Classification Report:
#                                        precision    recall  f1-score   support
#
#              account_discovery_domain       0.68      0.70      0.69     23003
#                                benign       0.51      0.42      0.46     23309
#                domain_trust_discovery       0.52      0.46      0.49     23141
#                group_policy_discovery       0.95      0.93      0.94     23008
#             network_service_discovery       0.91      0.96      0.93     23029
#         reconnaissance_scan_ip_blocks       0.97      0.98      0.97     23036
# reconnaissance_vulnerability_scanning       0.90      0.98      0.94     22971
#      reconnaissance_wordlist_scanning       0.99      0.99      0.99     23201
#               remote_system_discovery       0.85      0.97      0.90     23156
#
#                              accuracy                           0.82    207854
#                             macro avg       0.81      0.82      0.81    207854
#                          weighted avg       0.81      0.82      0.81    207854
#
# Epoch 1/10
# 23401/23401 ━━━━━━━━━━━━━━━━━━━━ 75s 3ms/step - accuracy: 0.4936 - loss: 1.3358 - val_accuracy: 0.7356 - val_loss: 0.7554
# Epoch 2/10
# 23401/23401 ━━━━━━━━━━━━━━━━━━━━ 72s 3ms/step - accuracy: 0.7365 - loss: 0.7099 - val_accuracy: 0.7923 - val_loss: 0.5641
# Epoch 3/10
# 23401/23401 ━━━━━━━━━━━━━━━━━━━━ 82s 3ms/step - accuracy: 0.7983 - loss: 0.5416 - val_accuracy: 0.8129 - val_loss: 0.4920
# Epoch 4/10
# 23401/23401 ━━━━━━━━━━━━━━━━━━━━ 78s 3ms/step - accuracy: 0.8227 - loss: 0.4713 - val_accuracy: 0.8333 - val_loss: 0.4381
# Epoch 5/10
# 23401/23401 ━━━━━━━━━━━━━━━━━━━━ 75s 3ms/step - accuracy: 0.8366 - loss: 0.4317 - val_accuracy: 0.8445 - val_loss: 0.3995
# Epoch 6/10
# 23401/23401 ━━━━━━━━━━━━━━━━━━━━ 84s 3ms/step - accuracy: 0.8453 - loss: 0.4062 - val_accuracy: 0.8539 - val_loss: 0.3892
# Epoch 7/10
# 23401/23401 ━━━━━━━━━━━━━━━━━━━━ 78s 3ms/step - accuracy: 0.8531 - loss: 0.3852 - val_accuracy: 0.8551 - val_loss: 0.3720
# Epoch 8/10
# 23401/23401 ━━━━━━━━━━━━━━━━━━━━ 77s 3ms/step - accuracy: 0.8601 - loss: 0.3671 - val_accuracy: 0.8657 - val_loss: 0.3460
# Epoch 9/10
# 23401/23401 ━━━━━━━━━━━━━━━━━━━━ 78s 3ms/step - accuracy: 0.8650 - loss: 0.3528 - val_accuracy: 0.8700 - val_loss: 0.3315
# Epoch 10/10
# 23401/23401 ━━━━━━━━━━━━━━━━━━━━ 76s 3ms/step - accuracy: 0.8690 - loss: 0.3410 - val_accuracy: 0.8744 - val_loss: 0.3269
# 6501/6501 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# adasyn.csv Accuracy: 0.8754723512273921
# Classification Report:
#                                        precision    recall  f1-score   support
#
#              account_discovery_domain       0.88      0.77      0.82     23170
#                                benign       0.93      0.37      0.53     23287
#                domain_trust_discovery       0.91      0.92      0.92     23051
#                group_policy_discovery       0.92      0.93      0.92     22987
#             network_service_discovery       1.00      1.00      1.00     22985
#         reconnaissance_scan_ip_blocks       0.97      1.00      0.99     23138
# reconnaissance_vulnerability_scanning       0.71      0.99      0.83     23251
#      reconnaissance_wordlist_scanning       1.00      0.98      0.99     23209
#               remote_system_discovery       0.70      0.94      0.80     22924
#
#                              accuracy                           0.88    208002
#                             macro avg       0.89      0.88      0.87    208002
#                          weighted avg       0.89      0.88      0.87    208002
#
# Epoch 1/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 77s 3ms/step - accuracy: 0.6200 - loss: 1.0472 - val_accuracy: 0.8662 - val_loss: 0.3886
# Epoch 2/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 75s 3ms/step - accuracy: 0.8625 - loss: 0.3799 - val_accuracy: 0.8811 - val_loss: 0.3213
# Epoch 3/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 75s 3ms/step - accuracy: 0.8836 - loss: 0.3199 - val_accuracy: 0.8891 - val_loss: 0.2900
# Epoch 4/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 75s 3ms/step - accuracy: 0.8932 - loss: 0.2910 - val_accuracy: 0.8990 - val_loss: 0.2797
# Epoch 5/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 75s 3ms/step - accuracy: 0.9002 - loss: 0.2702 - val_accuracy: 0.9054 - val_loss: 0.2530
# Epoch 6/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 75s 3ms/step - accuracy: 0.9045 - loss: 0.2551 - val_accuracy: 0.9066 - val_loss: 0.2443
# Epoch 7/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 72s 3ms/step - accuracy: 0.9095 - loss: 0.2420 - val_accuracy: 0.9159 - val_loss: 0.2282
# Epoch 8/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 75s 3ms/step - accuracy: 0.9131 - loss: 0.2320 - val_accuracy: 0.9195 - val_loss: 0.2153
# Epoch 9/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 71s 3ms/step - accuracy: 0.9166 - loss: 0.2234 - val_accuracy: 0.9228 - val_loss: 0.2138
# Epoch 10/10
# 23384/23384 ━━━━━━━━━━━━━━━━━━━━ 69s 3ms/step - accuracy: 0.9190 - loss: 0.2166 - val_accuracy: 0.9174 - val_loss: 0.2118
# 6496/6496 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# borderline_smote.csv Accuracy: 0.9166001135412357
# Classification Report:
#                                        precision    recall  f1-score   support
#
#              account_discovery_domain       0.97      0.87      0.92     23067
#                                benign       0.81      0.45      0.58     23253
#                domain_trust_discovery       0.86      0.98      0.92     22971
#                group_policy_discovery       0.97      1.00      0.98     23220
#             network_service_discovery       1.00      1.00      1.00     22987
#         reconnaissance_scan_ip_blocks       0.98      0.99      0.99     23023
# reconnaissance_vulnerability_scanning       0.75      0.99      0.85     22968
#      reconnaissance_wordlist_scanning       0.99      0.99      0.99     23202
#               remote_system_discovery       0.93      0.99      0.96     23163
#
#                              accuracy                           0.92    207854
#                             macro avg       0.92      0.92      0.91    207854
#                          weighted avg       0.92      0.92      0.91    207854
#
# Epoch 1/10
# 3740/3740 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6979 - loss: 0.7338 - val_accuracy: 0.9361 - val_loss: 0.2420
# Epoch 2/10
# 3740/3740 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9360 - loss: 0.2152 - val_accuracy: 0.9501 - val_loss: 0.1696
# Epoch 3/10
# 3740/3740 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9550 - loss: 0.1618 - val_accuracy: 0.9562 - val_loss: 0.1488
# Epoch 4/10
# 3740/3740 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9587 - loss: 0.1485 - val_accuracy: 0.9626 - val_loss: 0.1557
# Epoch 5/10
# 3740/3740 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9622 - loss: 0.1345 - val_accuracy: 0.9653 - val_loss: 0.1201
# Epoch 6/10
# 3740/3740 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9666 - loss: 0.1206 - val_accuracy: 0.9732 - val_loss: 0.1080
# Epoch 7/10
# 3740/3740 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9684 - loss: 0.1108 - val_accuracy: 0.9747 - val_loss: 0.1020
# Epoch 8/10
# 3740/3740 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9720 - loss: 0.1045 - val_accuracy: 0.9702 - val_loss: 0.1134
# Epoch 9/10
# 3740/3740 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9755 - loss: 0.0943 - val_accuracy: 0.9811 - val_loss: 0.0848
# Epoch 10/10
# 3740/3740 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9784 - loss: 0.0881 - val_accuracy: 0.9823 - val_loss: 0.0802
# 1039/1039 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# tomek_links.csv Accuracy: 0.9825210589651023
# Classification Report:
#                                        precision    recall  f1-score   support
#
#              account_discovery_domain       0.00      0.00      0.00         7
#                                benign       0.95      0.99      0.97      9535
#                domain_trust_discovery       0.00      0.00      0.00        58
#                group_policy_discovery       0.00      0.00      0.00         4
#             network_service_discovery       1.00      0.99      1.00     23225
#         reconnaissance_scan_ip_blocks       0.00      0.00      0.00        16
# reconnaissance_vulnerability_scanning       0.00      0.00      0.00       192
#      reconnaissance_wordlist_scanning       0.90      0.99      0.94       115
#               remote_system_discovery       0.00      0.00      0.00        88
#
#                              accuracy                           0.98     33240
#                             macro avg       0.32      0.33      0.32     33240
#                          weighted avg       0.97      0.98      0.98     33240
#
# Epoch 1/10
# 22972/22972 ━━━━━━━━━━━━━━━━━━━━ 67s 3ms/step - accuracy: 0.5980 - loss: 1.1426 - val_accuracy: 0.8044 - val_loss: 0.6119
# Epoch 2/10
# 22972/22972 ━━━━━━━━━━━━━━━━━━━━ 66s 3ms/step - accuracy: 0.8292 - loss: 0.5331 - val_accuracy: 0.8735 - val_loss: 0.3932
# Epoch 3/10
# 22972/22972 ━━━━━━━━━━━━━━━━━━━━ 68s 3ms/step - accuracy: 0.8724 - loss: 0.3927 - val_accuracy: 0.8979 - val_loss: 0.3318
# Epoch 4/10
# 22972/22972 ━━━━━━━━━━━━━━━━━━━━ 72s 3ms/step - accuracy: 0.8955 - loss: 0.3292 - val_accuracy: 0.9209 - val_loss: 0.2769
# Epoch 5/10
# 22972/22972 ━━━━━━━━━━━━━━━━━━━━ 75s 3ms/step - accuracy: 0.9185 - loss: 0.2773 - val_accuracy: 0.9238 - val_loss: 0.2473
# Epoch 6/10
# 22972/22972 ━━━━━━━━━━━━━━━━━━━━ 75s 3ms/step - accuracy: 0.9313 - loss: 0.2427 - val_accuracy: 0.9307 - val_loss: 0.2275
# Epoch 7/10
# 22972/22972 ━━━━━━━━━━━━━━━━━━━━ 76s 3ms/step - accuracy: 0.9372 - loss: 0.2207 - val_accuracy: 0.9433 - val_loss: 0.1992
# Epoch 8/10
# 22972/22972 ━━━━━━━━━━━━━━━━━━━━ 67s 3ms/step - accuracy: 0.9424 - loss: 0.2020 - val_accuracy: 0.9426 - val_loss: 0.1853
# Epoch 9/10
# 22972/22972 ━━━━━━━━━━━━━━━━━━━━ 84s 3ms/step - accuracy: 0.9463 - loss: 0.1862 - val_accuracy: 0.9512 - val_loss: 0.1667
# Epoch 10/10
# 22972/22972 ━━━━━━━━━━━━━━━━━━━━ 69s 3ms/step - accuracy: 0.9499 - loss: 0.1738 - val_accuracy: 0.9462 - val_loss: 0.1786
# 6381/6381 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# smoteenn.csv Accuracy: 0.9459370775951574
# Classification Report:
#                                        precision    recall  f1-score   support
#
#              account_discovery_domain       0.89      0.85      0.87     22784
#                                benign       0.95      0.80      0.87     21615
#                domain_trust_discovery       0.99      0.95      0.97     22536
#                group_policy_discovery       0.94      0.95      0.95     23026
#             network_service_discovery       1.00      1.00      1.00     22956
#         reconnaissance_scan_ip_blocks       0.99      0.99      0.99     23013
# reconnaissance_vulnerability_scanning       0.95      0.99      0.97     22359
#      reconnaissance_wordlist_scanning       1.00      1.00      1.00     23256
#               remote_system_discovery       0.83      0.98      0.90     22643
#
#                              accuracy                           0.95    204188
#                             macro avg       0.95      0.95      0.94    204188
#                          weighted avg       0.95      0.95      0.95    204188
#
# Epoch 1/10
# 23313/23313 ━━━━━━━━━━━━━━━━━━━━ 70s 3ms/step - accuracy: 0.5735 - loss: 1.1860 - val_accuracy: 0.7863 - val_loss: 0.6733
# Epoch 2/10
# 23313/23313 ━━━━━━━━━━━━━━━━━━━━ 69s 3ms/step - accuracy: 0.8072 - loss: 0.6126 - val_accuracy: 0.8468 - val_loss: 0.5589
# Epoch 3/10
# 23313/23313 ━━━━━━━━━━━━━━━━━━━━ 69s 3ms/step - accuracy: 0.8533 - loss: 0.4588 - val_accuracy: 0.8755 - val_loss: 0.3955
# Epoch 4/10
# 23313/23313 ━━━━━━━━━━━━━━━━━━━━ 70s 3ms/step - accuracy: 0.8915 - loss: 0.3498 - val_accuracy: 0.9132 - val_loss: 0.2926
# Epoch 5/10
# 23313/23313 ━━━━━━━━━━━━━━━━━━━━ 70s 3ms/step - accuracy: 0.9140 - loss: 0.2937 - val_accuracy: 0.9250 - val_loss: 0.2641
# Epoch 6/10
# 23313/23313 ━━━━━━━━━━━━━━━━━━━━ 70s 3ms/step - accuracy: 0.9246 - loss: 0.2604 - val_accuracy: 0.9259 - val_loss: 0.2367
# Epoch 7/10
# 23313/23313 ━━━━━━━━━━━━━━━━━━━━ 71s 3ms/step - accuracy: 0.9314 - loss: 0.2365 - val_accuracy: 0.9412 - val_loss: 0.2330
# Epoch 8/10
# 23313/23313 ━━━━━━━━━━━━━━━━━━━━ 71s 3ms/step - accuracy: 0.9357 - loss: 0.2177 - val_accuracy: 0.9431 - val_loss: 0.1907
# Epoch 9/10
# 23313/23313 ━━━━━━━━━━━━━━━━━━━━ 71s 3ms/step - accuracy: 0.9406 - loss: 0.1995 - val_accuracy: 0.9479 - val_loss: 0.1924
# Epoch 10/10
# 23313/23313 ━━━━━━━━━━━━━━━━━━━━ 71s 3ms/step - accuracy: 0.9434 - loss: 0.1906 - val_accuracy: 0.9458 - val_loss: 0.1792
# 6476/6476 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# smotetomek.csv Accuracy: 0.9447881478621755
# Classification Report:
#                                        precision    recall  f1-score   support
#
#              account_discovery_domain       0.93      0.81      0.87     23164
#                                benign       0.90      0.81      0.85     22718
#                domain_trust_discovery       0.98      0.96      0.97     22862
#                group_policy_discovery       0.95      0.96      0.96     23048
#             network_service_discovery       1.00      1.00      1.00     23213
#         reconnaissance_scan_ip_blocks       0.98      1.00      0.99     23065
# reconnaissance_vulnerability_scanning       0.93      0.99      0.96     22871
#      reconnaissance_wordlist_scanning       1.00      1.00      1.00     23202
#               remote_system_discovery       0.84      0.98      0.90     23077
#
#                              accuracy                           0.94    207220
#                             macro avg       0.95      0.94      0.94    207220
#                          weighted avg       0.95      0.94      0.94    207220
